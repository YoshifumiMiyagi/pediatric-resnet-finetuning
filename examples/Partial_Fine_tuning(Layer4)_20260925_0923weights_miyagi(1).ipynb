# %%
# !pip install git+https://github.com/YoshifumiMiyagi/pediatric-resnet-finetuning.git
# Out:
# Collecting git+https://github.com/YoshifumiMiyagi/pediatric-resnet-finetuning.git
#   Cloning https://github.com/YoshifumiMiyagi/pediatric-resnet-finetuning.git to /tmp/pip-req-build-_9ygzxat
#   Running command git clone --filter=blob:none --quiet https://github.com/YoshifumiMiyagi/pediatric-resnet-finetuning.git /tmp/pip-req-build-_9ygzxat
#   Resolved https://github.com/YoshifumiMiyagi/pediatric-resnet-finetuning.git to commit 4d5373af6d42b6dffdc3b5dcd23423f22a2c3dc4
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: torch>=2.0 in /usr/local/lib/python3.13/dist-packages (from pediatric-resnet-ft==0.1.3) (2.11.0+cu128)
# Requirement already satisfied: torchvision>=0.15 in /usr/local/lib/python3.13/dist-packages (from pediatric-resnet-ft==0.1.3) (0.26.0+cu128)
# Requirement already satisfied: numpy>=1.23 in /usr/local/lib/python3.13/dist-packages (from pediatric-resnet-ft==0.1.3) (2.1.3)
# Requirement already satisfied: pandas>=1.5 in /usr/local/lib/python3.13/dist-packages (from pediatric-resnet-ft==0.1.3) (2.2.3)
# Requirement already satisfied: scikit-learn>=1.2 in /usr/local/lib/python3.13/dist-packages (from pediatric-resnet-ft==0.1.3) (1.6.1)
# Requirement already satisfied: Pillow>=9.0 in /usr/local/lib/python3.13/dist-packages (from pediatric-resnet-ft==0.1.3) (11.3.0)
# Requirement already satisfied: openpyxl>=3.1 in /usr/local/lib/python3.13/dist-packages (from pediatric-resnet-ft==0.1.3) (3.1.5)
# Requirement already satisfied: et-xmlfile in /usr/local/lib/python3.13/dist-packages (from openpyxl>=3.1->pediatric-resnet-ft==0.1.3) (2.0.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.13/dist-packages (from pandas>=1.5->pediatric-resnet-ft==0.1.3) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.13/dist-packages (from pandas>=1.5->pediatric-resnet-ft==0.1.3) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.13/dist-packages (from pandas>=1.5->pediatric-resnet-ft==0.1.3) (2026.3)
# Requirement already satisfied: scipy>=1.6.0 in /usr/local/lib/python3.13/dist-packages (from scikit-learn>=1.2->pediatric-resnet-ft==0.1.3) (1.16.3)
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.13/dist-packages (from scikit-learn>=1.2->pediatric-resnet-ft==0.1.3) (1.6.0)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.13/dist-packages (from scikit-learn>=1.2->pediatric-resnet-ft==0.1.3) (3.6.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.13/dist-packages (from torch>=2.0->pediatric-resnet-ft==0.1.3) (3.32.5)
# Requirement already satisfied: typing-extensions>=4.10.0 in /usr/local/lib/python3.13/dist-packages (from torch>=2.0->pediatric-resnet-ft==0.1.3) (4.16.0)
# Requirement already satisfied: setuptools<82 in /usr/local/lib/python3.13/dist-packages (from torch>=2.0->pediatric-resnet-ft==0.1.3) (80.10.2)
# Requirement already satisfied: sympy>=1.13.3 in /usr/local/lib/python3.13/dist-packages (from torch>=2.0->pediatric-resnet-ft==0.1.3) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in /usr/local/lib/python3.13/dist-packages (from torch>=2.0->pediatric-resnet-ft==0.1.3) (3.6.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.13/dist-packages (from torch>=2.0->pediatric-resnet-ft==0.1.3) (3.1.6)
# Requirement already satisfied: fsspec>=0.8.5 in /usr/local/lib/python3.13/dist-packages (from torch>=2.0->pediatric-resnet-ft==0.1.3) (2025.12.0)
# Requirement already satisfied: cuda-toolkit==12.8.1 in /usr/local/lib/python3.13/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch>=2.0->pediatric-resnet-ft==0.1.3) (12.8.1)
# Requirement already satisfied: cuda-bindings<13,>=12.9.4 in /usr/local/lib/python3.13/dist-packages (from torch>=2.0->pediatric-resnet-ft==0.1.3) (12.9.7)
# Requirement already satisfied: nvidia-cudnn-cu12==9.19.0.56 in /usr/local/lib/python3.13/dist-packages (from torch>=2.0->pediatric-resnet-ft==0.1.3) (9.19.0.56)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.7.1 in /usr/local/lib/python3.13/dist-packages (from torch>=2.0->pediatric-resnet-ft==0.1.3) (0.7.1)
# Requirement already satisfied: nvidia-nccl-cu12==2.28.9 in /usr/local/lib/python3.13/dist-packages (from torch>=2.0->pediatric-resnet-ft==0.1.3) (2.28.9)
# Requirement already satisfied: nvidia-nvshmem-cu12==3.4.5 in /usr/local/lib/python3.13/dist-packages (from torch>=2.0->pediatric-resnet-ft==0.1.3) (3.4.5)
# Requirement already satisfied: triton==3.6.0 in /usr/local/lib/python3.13/dist-packages (from torch>=2.0->pediatric-resnet-ft==0.1.3) (3.6.0)
# Requirement already satisfied: nvidia-cublas-cu12==12.8.4.1.* in /usr/local/lib/python3.13/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch>=2.0->pediatric-resnet-ft==0.1.3) (12.8.4.1)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.8.90.* in /usr/local/lib/python3.13/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch>=2.0->pediatric-resnet-ft==0.1.3) (12.8.90)
# Requirement already satisfied: nvidia-cufft-cu12==11.3.3.83.* in /usr/local/lib/python3.13/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch>=2.0->pediatric-resnet-ft==0.1.3) (11.3.3.83)
# Requirement already satisfied: nvidia-cufile-cu12==1.13.1.3.* in /usr/local/lib/python3.13/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch>=2.0->pediatric-resnet-ft==0.1.3) (1.13.1.3)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.8.90.* in /usr/local/lib/python3.13/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch>=2.0->pediatric-resnet-ft==0.1.3) (12.8.90)
# Requirement already satisfied: nvidia-curand-cu12==10.3.9.90.* in /usr/local/lib/python3.13/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch>=2.0->pediatric-resnet-ft==0.1.3) (10.3.9.90)
# Requirement already satisfied: nvidia-cusolver-cu12==11.7.3.90.* in /usr/local/lib/python3.13/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch>=2.0->pediatric-resnet-ft==0.1.3) (11.7.3.90)
# Requirement already satisfied: nvidia-cusparse-cu12==12.5.8.93.* in /usr/local/lib/python3.13/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch>=2.0->pediatric-resnet-ft==0.1.3) (12.5.8.93)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.8.93.* in /usr/local/lib/python3.13/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch>=2.0->pediatric-resnet-ft==0.1.3) (12.8.93)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.8.93.* in /usr/local/lib/python3.13/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch>=2.0->pediatric-resnet-ft==0.1.3) (12.8.93)
# Requirement already satisfied: nvidia-nvtx-cu12==12.8.90.* in /usr/local/lib/python3.13/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch>=2.0->pediatric-resnet-ft==0.1.3) (12.8.90)
# Requirement already satisfied: cuda-pathfinder~=1.1 in /usr/local/lib/python3.13/dist-packages (from cuda-bindings<13,>=12.9.4->torch>=2.0->pediatric-resnet-ft==0.1.3) (1.8.0)
# Requirement already satisfied: cloudpickle>=3.0 in /usr/local/lib/python3.13/dist-packages (from joblib>=1.2.0->scikit-learn>=1.2->pediatric-resnet-ft==0.1.3) (3.1.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.13/dist-packages (from python-dateutil>=2.8.2->pandas>=1.5->pediatric-resnet-ft==0.1.3) (1.17.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.13/dist-packages (from sympy>=1.13.3->torch>=2.0->pediatric-resnet-ft==0.1.3) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.13/dist-packages (from jinja2->torch>=2.0->pediatric-resnet-ft==0.1.3) (3.0.3)

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# # 0-5歳 partial Fine-tuning (Layer4)

# %%
from pediatric_resnet_ft import build_dataset_csv

df_young = build_dataset_csv(
    metadata_path="/content/drive/MyDrive/PedAI_ChestXp/For_finetuning/QC/merged_reviewer_results_260906.xlsx",
    image_dir="/content/drive/MyDrive/PedAI_ChestXp/For_finetuning/QC/age_01_05",
    output_csv="/content/drive/MyDrive/QC/age_01_05.csv",
)

print(df_young.shape)
display(df_young.head())

print("\nImages:", len(df_young))
print("Patients:", df_young["patient_id"].nunique())
print("\nSex:")
print(df_young["label"].value_counts())
# Out:
# (116, 6)
#   patient_id        image_name  \
# 0       2450  00002450_000.png
# 1       2555  00002555_000.png
# 2       4028  00004028_000.png
# 3       4535  00004535_000.png
# 4       4987  00004987_000.png
#
#                                                 path  label  age  age_group
# 0  /content/drive/.shortcut-targets-by-id/18RK_Lq...      0    4  age_01_05
# 1  /content/drive/.shortcut-targets-by-id/18RK_Lq...      1    5  age_01_05
# 2  /content/drive/.shortcut-targets-by-id/18RK_Lq...      0    5  age_01_05
# 3  /content/drive/.shortcut-targets-by-id/18RK_Lq...      0    5  age_01_05
# 4  /content/drive/.shortcut-targets-by-id/18RK_Lq...      1    4  age_01_05
# Images: 116
# Patients: 103
#
# Sex:
# label
# 1    59
# 0    57
# Name: count, dtype: int64

# %%
# from pediatric_resnet_ft import run_cv

# results = run_cv(
#     csv_path="/content/drive/MyDrive/QC/age_01_05.csv",

#     pretrained="none",
#     #pretrained_path="/content/drive/MyDrive/colab_最小データセット/models/resnet50_pa_adult.pt",

#     mode="layer4",

#     seeds=[42],
#     n_splits=5,

#     epochs=3,
#     batch_size=16,

#     id_col="patient_id",

#     output_dir="/content/drive/MyDrive/QC/results/test_young_layer4",
# )

# %%
# results = run_cv(
#     csv_path="/content/drive/MyDrive/QC/age_01_05.csv",

#     pretrained="imagenet",
#     #pretrained_path="/content/drive/MyDrive/colab_最小データセット/models/resnet50_pa_adult.pt",

#     mode="layer4",

#     seeds=[42],
#     n_splits=5,

#     epochs=3,
#     batch_size=16,

#     id_col="patient_id",

#     output_dir="/content/drive/MyDrive/QC/results/test_young_layer4",
# )

# %%
# import torch
# import os

# CKPT_PATH = (
#     "/content/drive/MyDrive/colab_最小データセット/models/"
#     "/resnet50_pa_adult_v4.pt"
# )

# WEIGHTS_PATH = (
#     "/content/drive/MyDrive/colab_最小データセット/models/"
#     "/resnet50_pa_adult_v4_weights.pt"
# )

# # 自分で作成した信頼できるcheckpointなので weights_only=False
# ckpt = torch.load(
#     CKPT_PATH,
#     map_location="cpu",
#     weights_only=False
# )

# print("Checkpoint keys:")
# print(ckpt.keys())

# # 今回のcheckpointではここ
# state_dict = ckpt["model_state_dict"]

# # 純粋なstate_dictだけ保存
# torch.save(
#     state_dict,
#     WEIGHTS_PATH
# )

# print("\nSaved:")
# print(WEIGHTS_PATH)
# print(f"Parameters/tensors: {len(state_dict)}")

# %%
from pediatric_resnet_ft import run_cv

results = run_cv(
    csv_path="/content/drive/MyDrive/QC/age_01_05.csv",

    pretrained="adult",
    pretrained_path="/content/drive/MyDrive/colab_最小データセット/models/Morimoto_Adult_AgeFixed_20260923_共有用/resnet50_pa_adult_agefixed_morimoto_20260923_weights.pt",

    mode="layer4",

    seeds=[42],
    n_splits=5,

    epochs=30,
    batch_size=16,

    id_col="patient_id",

    output_dir="/content/drive/MyDrive/QC/results/test_young_layer4",
)
# Out:
# Device: cuda (Tesla T4)
# CV: 1 seed(s) x 5 folds = 5 models
#
# Seed 1/1 (seed=42)
#   Fold 1/5 | train=93 valid=23
#     Epoch 01/30 | train loss=1.6216 AUC=0.6900 | val loss=4.1025 AUC=0.6333
#     Epoch 02/30 | train loss=1.6314 AUC=0.6426 | val loss=2.6764 AUC=0.6333
#     Epoch 03/30 | train loss=0.9638 AUC=0.7373 | val loss=1.9993 AUC=0.6333
#     Epoch 04/30 | train loss=0.6561 AUC=0.8091 | val loss=1.6484 AUC=0.5778
#     Epoch 05/30 | train loss=0.6006 AUC=0.8114 | val loss=1.5115 AUC=0.5667
#     Epoch 06/30 | train loss=0.5148 AUC=0.8424 | val loss=1.3853 AUC=0.5333
#     Epoch 07/30 | train loss=0.4286 AUC=0.8705 | val loss=1.2148 AUC=0.5778
#     Epoch 08/30 | train loss=0.3631 AUC=0.9212 | val loss=1.2538 AUC=0.5889
#     Epoch 09/30 | train loss=0.3682 AUC=0.9151 | val loss=1.2047 AUC=0.6111
#     Epoch 10/30 | train loss=0.3337 AUC=0.9353 | val loss=1.0716 AUC=0.6333
#     Epoch 11/30 | train loss=0.2688 AUC=0.9648 | val loss=1.0292 AUC=0.6333
#     Epoch 12/30 | train loss=0.2899 AUC=0.9522 | val loss=1.0139 AUC=0.6333
#     Epoch 13/30 | train loss=0.2377 AUC=0.9737 | val loss=1.0083 AUC=0.6667
#     Epoch 14/30 | train loss=0.2201 AUC=0.9845 | val loss=0.9898 AUC=0.6667
#     Epoch 15/30 | train loss=0.1928 AUC=0.9878 | val loss=1.1274 AUC=0.6444
#     Epoch 16/30 | train loss=0.1285 AUC=0.9977 | val loss=1.1104 AUC=0.6444
#     Epoch 17/30 | train loss=0.1558 AUC=0.9939 | val loss=1.1304 AUC=0.6222
#     Epoch 18/30 | train loss=0.1144 AUC=0.9991 | val loss=1.1025 AUC=0.6444
#     Epoch 19/30 | train loss=0.1652 AUC=0.9977 | val loss=1.0427 AUC=0.6333
#     Epoch 20/30 | train loss=0.1327 AUC=0.9967 | val loss=1.0412 AUC=0.6333
#     Epoch 21/30 | train loss=0.0878 AUC=1.0000 | val loss=1.0437 AUC=0.6333
#     Epoch 22/30 | train loss=0.1299 AUC=0.9934 | val loss=0.9973 AUC=0.6444
#     Epoch 23/30 | train loss=0.0786 AUC=1.0000 | val loss=1.0000 AUC=0.6444
#     Epoch 24/30 | train loss=0.0827 AUC=1.0000 | val loss=1.0732 AUC=0.6444
#     Epoch 25/30 | train loss=0.0806 AUC=1.0000 | val loss=1.0898 AUC=0.6333
#     Epoch 26/30 | train loss=0.0931 AUC=1.0000 | val loss=1.0528 AUC=0.6333
#     Epoch 27/30 | train loss=0.0738 AUC=1.0000 | val loss=1.0658 AUC=0.6556
#     Epoch 28/30 | train loss=0.0845 AUC=1.0000 | val loss=1.0818 AUC=0.6667
#     Epoch 29/30 | train loss=0.0929 AUC=0.9995 | val loss=1.1473 AUC=0.6444
#     Epoch 30/30 | train loss=0.0941 AUC=0.9991 | val loss=1.1009 AUC=0.6333
#   Fold 1/5 finished | best AUC=0.6667
#   Fold 2/5 | train=93 valid=23
#     Epoch 01/30 | train loss=2.1892 AUC=0.5873 | val loss=1.2010 AUC=0.6667
#     Epoch 02/30 | train loss=1.2753 AUC=0.6737 | val loss=1.2115 AUC=0.6750
#     Epoch 03/30 | train loss=0.8566 AUC=0.7512 | val loss=1.2110 AUC=0.6583
#     Epoch 04/30 | train loss=0.7455 AUC=0.7722 | val loss=1.2125 AUC=0.6750
#     Epoch 05/30 | train loss=0.5198 AUC=0.8459 | val loss=1.1244 AUC=0.6583
#     Epoch 06/30 | train loss=0.4091 AUC=0.8954 | val loss=1.0435 AUC=0.6583
#     Epoch 07/30 | train loss=0.4012 AUC=0.8978 | val loss=1.0357 AUC=0.6583
#     Epoch 08/30 | train loss=0.2823 AUC=0.9608 | val loss=1.0942 AUC=0.6333
#     Epoch 09/30 | train loss=0.2945 AUC=0.9454 | val loss=1.1793 AUC=0.6333
#     Epoch 10/30 | train loss=0.2208 AUC=0.9734 | val loss=1.2258 AUC=0.6250
#     Epoch 11/30 | train loss=0.2392 AUC=0.9734 | val loss=1.2280 AUC=0.6250
#     Epoch 12/30 | train loss=0.1781 AUC=0.9818 | val loss=1.2339 AUC=0.6167
#     Epoch 13/30 | train loss=0.1487 AUC=0.9953 | val loss=1.2439 AUC=0.6250
#     Epoch 14/30 | train loss=0.1320 AUC=0.9972 | val loss=1.2603 AUC=0.6333
#     Epoch 15/30 | train loss=0.1173 AUC=0.9977 | val loss=1.2699 AUC=0.6250
#     Epoch 16/30 | train loss=0.1228 AUC=0.9963 | val loss=1.2968 AUC=0.6250
#     Epoch 17/30 | train loss=0.0823 AUC=1.0000 | val loss=1.2985 AUC=0.6083
#     Epoch 18/30 | train loss=0.1204 AUC=0.9949 | val loss=1.3483 AUC=0.6083
#     Epoch 19/30 | train loss=0.0805 AUC=1.0000 | val loss=1.3673 AUC=0.5917
#     Epoch 20/30 | train loss=0.1050 AUC=0.9972 | val loss=1.4022 AUC=0.5833
#     Epoch 21/30 | train loss=0.1210 AUC=0.9939 | val loss=1.4454 AUC=0.5833
#     Epoch 22/30 | train loss=0.0804 AUC=1.0000 | val loss=1.4551 AUC=0.5833
#     Epoch 23/30 | train loss=0.0404 AUC=1.0000 | val loss=1.4579 AUC=0.5833
#     Epoch 24/30 | train loss=0.0515 AUC=0.9995 | val loss=1.4604 AUC=0.5833
#     Epoch 25/30 | train loss=0.0652 AUC=1.0000 | val loss=1.4743 AUC=0.5833
#     Epoch 26/30 | train loss=0.0771 AUC=0.9995 | val loss=1.4978 AUC=0.5333
#     Epoch 27/30 | train loss=0.0898 AUC=0.9981 | val loss=1.5013 AUC=0.5333
#     Epoch 28/30 | train loss=0.0676 AUC=1.0000 | val loss=1.5023 AUC=0.5250
#     Epoch 29/30 | train loss=0.0591 AUC=1.0000 | val loss=1.5189 AUC=0.5250
#     Epoch 30/30 | train loss=0.0579 AUC=1.0000 | val loss=1.5019 AUC=0.5333
#   Fold 5/5 finished | best AUC=0.5917
# Seed 42 OOF AUC = 0.6399
#
# Finished. Mean-prediction OOF AUC = 0.6399
# Saved to: /content/drive/MyDrive/QC/results/test_young_layer4

# %%
import numpy as np
import pandas as pd
from sklearn.metrics import roc_auc_score

# ============================================================
# Settings
# ============================================================
OOF_PATH = (
    "/content/drive/MyDrive/QC/results/"
    "test_young_layer4/oof_predictions.csv"
)

PATIENT_COL = "patient_id"
LABEL_COL = "label"

SEEDS = [42, ]
#SEEDS = [42, 43, 44, 45, 46]   # 本解析では5 seeds
N_BOOT = 2000
RANDOM_STATE = 12345


# ============================================================
# Load
# ============================================================
df = pd.read_csv(OOF_PATH)

pred_cols = [f"oof_seed{s}" for s in SEEDS]

missing = [c for c in pred_cols if c not in df.columns]
if missing:
    raise ValueError(
        f"Missing prediction columns: {missing}\n"
        "まだ1 seedしか実行していない場合は SEEDS=[42] にしてください。"
    )

print("Images:", len(df))
print("Patients:", df[PATIENT_COL].nunique())


# ============================================================
# 1. Patient-level aggregation
#    複数画像を持つ患者では予測確率を平均
# ============================================================
# 患者内でlabelが一貫しているか確認
label_check = df.groupby(PATIENT_COL)[LABEL_COL].nunique()

if (label_check > 1).any():
    bad_ids = label_check[label_check > 1].index.tolist()
    raise ValueError(
        f"同一患者内でlabelが不一致です: {bad_ids[:10]}"
    )

agg_dict = {
    LABEL_COL: "first",
}

for col in pred_cols:
    agg_dict[col] = "mean"

patient_df = (
    df.groupby(PATIENT_COL, as_index=False)
      .agg(agg_dict)
)

print("\nPatient-level dataset")
print(patient_df.shape)
print(patient_df[LABEL_COL].value_counts())


# ============================================================
# 2. Seedごとの patient-level OOF AUROC
# ============================================================
seed_results = []

y = patient_df[LABEL_COL].astype(int).to_numpy()

for seed in SEEDS:
    col = f"oof_seed{seed}"
    pred = patient_df[col].to_numpy()

    auc = roc_auc_score(y, pred)

    seed_results.append({
        "seed": seed,
        "patient_level_auc": auc
    })

seed_results = pd.DataFrame(seed_results)

mean_auc = seed_results["patient_level_auc"].mean()

# sample SD
sd_auc = seed_results["patient_level_auc"].std(ddof=1) if len(SEEDS) > 1 else np.nan


# ============================================================
# 3. Primary prediction
#    5 seedsのpatient-level OOF予測を平均
# ============================================================
patient_df["oof_mean_seeds"] = patient_df[pred_cols].mean(axis=1)

primary_pred = patient_df["oof_mean_seeds"].to_numpy()

primary_auc = roc_auc_score(y, primary_pred)


# ============================================================
# 4. Patient-level stratified bootstrap
#
#    患者単位でresampling。
#    Female / Maleをそれぞれ復元抽出してclass balanceを保持。
# ============================================================
def bootstrap_auc_patient_level(
    y_true,
    y_pred,
    n_boot=5000,
    random_state=12345
):
    y_true = np.asarray(y_true)
    y_pred = np.asarray(y_pred)

    rng = np.random.default_rng(random_state)

    idx0 = np.where(y_true == 0)[0]
    idx1 = np.where(y_true == 1)[0]

    boot_aucs = []

    for _ in range(n_boot):

        # classごとにpatientを復元抽出
        boot0 = rng.choice(
            idx0,
            size=len(idx0),
            replace=True
        )

        boot1 = rng.choice(
            idx1,
            size=len(idx1),
            replace=True
        )

        boot_idx = np.concatenate([boot0, boot1])

        auc = roc_auc_score(
            y_true[boot_idx],
            y_pred[boot_idx]
        )

        boot_aucs.append(auc)

    boot_aucs = np.asarray(boot_aucs)

    ci_lower = np.percentile(boot_aucs, 2.5)
    ci_upper = np.percentile(boot_aucs, 97.5)

    return ci_lower, ci_upper, boot_aucs


ci_low, ci_high, boot_aucs = bootstrap_auc_patient_level(
    y,
    primary_pred,
    n_boot=N_BOOT,
    random_state=RANDOM_STATE
)


# ============================================================
# 5. Results
# ============================================================
print("\n==========================================")
print("PRIMARY ANALYSIS")
print("==========================================")

print(
    f"Patient-level AUROC = {primary_auc:.3f} "
    f"(95% CI {ci_low:.3f}-{ci_high:.3f})"
)

print("\n==========================================")
print("SEED-LEVEL REPRODUCIBILITY")
print("==========================================")

display(seed_results)

if len(SEEDS) > 1:
    print(
        f"5-seed AUROC mean ± SD = "
        f"{mean_auc:.3f} ± {sd_auc:.3f}"
    )
else:
    print(
        f"Seed {SEEDS[0]} AUROC = {mean_auc:.3f}"
    )


# ============================================================
# 6. Save
# ============================================================
summary = pd.DataFrame([{
    "n_patients": len(patient_df),
    "primary_patient_auc": primary_auc,
    "bootstrap_ci_lower": ci_low,
    "bootstrap_ci_upper": ci_high,
    "n_bootstrap": N_BOOT,
    "seed_auc_mean": mean_auc,
    "seed_auc_sd": sd_auc,
    "n_seeds": len(SEEDS),
}])

summary.to_csv(
    "/content/drive/MyDrive/QC/results/"
    "patient_level_auc_summary.csv",
    index=False
)

seed_results.to_csv(
    "/content/drive/MyDrive/QC/results/"
    "patient_level_seed_auc.csv",
    index=False
)

patient_df.to_csv(
    "/content/drive/MyDrive/QC/results/"
    "patient_level_oof_predictions.csv",
    index=False
)

print("\nSaved.")
# Out:
# Images: 116
# Patients: 103
#
# Patient-level dataset
# (103, 3)
# label
# 1    54
# 0    49
# Name: count, dtype: int64
#
# ==========================================
# PRIMARY ANALYSIS
# ==========================================
# Patient-level AUROC = 0.641 (95% CI 0.536-0.749)
#
# ==========================================
# SEED-LEVEL REPRODUCIBILITY
# ==========================================
#    seed  patient_level_auc
# 0    42           0.640967
# Seed 42 AUROC = 0.641
#
# Saved.

# %% [markdown]
# # 6-11

# %%
from pediatric_resnet_ft import build_dataset_csv

df_young = build_dataset_csv(
    metadata_path="/content/drive/MyDrive/PedAI_ChestXp/For_finetuning/QC/merged_reviewer_results_260906.xlsx",
    image_dir="/content/drive/MyDrive/PedAI_ChestXp/For_finetuning/QC/age_06_11",
    output_csv="/content/drive/MyDrive/QC/age_06_11.csv",
)

print(df_young.shape)
display(df_young.head())

print("\nImages:", len(df_young))
print("Patients:", df_young["patient_id"].nunique())
print("\nSex:")
print(df_young["label"].value_counts())
# Out:
# (404, 6)
#   patient_id        image_name  \
# 0       1485  00001485_000.png
# 1       1676  00001676_000.png
# 2       1676  00001676_001.png
# 3       1717  00001717_000.png
# 4       1717  00001717_001.png
#
#                                                 path  label  age  age_group
# 0  /content/drive/.shortcut-targets-by-id/18RK_Lq...      0   11  age_06_11
# 1  /content/drive/.shortcut-targets-by-id/18RK_Lq...      0    8  age_06_11
# 2  /content/drive/.shortcut-targets-by-id/18RK_Lq...      0   11  age_06_11
# 3  /content/drive/.shortcut-targets-by-id/18RK_Lq...      0    9  age_06_11
# 4  /content/drive/.shortcut-targets-by-id/18RK_Lq...      0    9  age_06_11
# Images: 404
# Patients: 296
#
# Sex:
# label
# 1    219
# 0    185
# Name: count, dtype: int64

# %%
from pediatric_resnet_ft import run_cv

results = run_cv(
    csv_path="/content/drive/MyDrive/QC/age_06_11.csv",

    pretrained="adult",
    pretrained_path="/content/drive/MyDrive/colab_最小データセット/models/Morimoto_Adult_AgeFixed_20260923_共有用/resnet50_pa_adult_agefixed_morimoto_20260923_weights.pt",

    mode="layer4",

    seeds=[42],
    n_splits=5,

    epochs=30,
    batch_size=16,

    id_col="patient_id",

    output_dir="/content/drive/MyDrive/QC/results/test_school_layer4",
)
# Out:
# Device: cuda (Tesla T4)
# CV: 1 seed(s) x 5 folds = 5 models
#
# Seed 1/1 (seed=42)
#   Fold 1/5 | train=327 valid=77
#     Epoch 01/30 | train loss=1.5833 AUC=0.6975 | val loss=0.9684 AUC=0.6838
#     Epoch 02/30 | train loss=0.7289 AUC=0.7797 | val loss=0.7479 AUC=0.7000
#     Epoch 03/30 | train loss=0.6000 AUC=0.7862 | val loss=0.6640 AUC=0.7142
#     Epoch 04/30 | train loss=0.4968 AUC=0.8382 | val loss=0.6261 AUC=0.7338
#     Epoch 05/30 | train loss=0.4228 AUC=0.8949 | val loss=0.6275 AUC=0.7439
#     Epoch 06/30 | train loss=0.3926 AUC=0.9108 | val loss=0.6300 AUC=0.7493
#     Epoch 07/30 | train loss=0.3182 AUC=0.9531 | val loss=0.6310 AUC=0.7486
#     Epoch 08/30 | train loss=0.2766 AUC=0.9645 | val loss=0.6316 AUC=0.7595
#     Epoch 09/30 | train loss=0.1963 AUC=0.9872 | val loss=0.7272 AUC=0.7655
#     Epoch 10/30 | train loss=0.1389 AUC=0.9919 | val loss=0.6977 AUC=0.7689
#     Epoch 11/30 | train loss=0.1090 AUC=0.9970 | val loss=0.7389 AUC=0.7750
#     Epoch 12/30 | train loss=0.0648 AUC=0.9995 | val loss=0.7206 AUC=0.7797
#     Epoch 13/30 | train loss=0.0479 AUC=0.9998 | val loss=0.7591 AUC=0.7831
#     Epoch 14/30 | train loss=0.0427 AUC=1.0000 | val loss=0.7767 AUC=0.7865
#     Epoch 15/30 | train loss=0.0378 AUC=0.9999 | val loss=0.7876 AUC=0.7764
#     Epoch 16/30 | train loss=0.0284 AUC=1.0000 | val loss=0.8072 AUC=0.7818
#     Epoch 17/30 | train loss=0.0290 AUC=0.9998 | val loss=0.7932 AUC=0.7736
#     Epoch 18/30 | train loss=0.0228 AUC=1.0000 | val loss=0.8375 AUC=0.7764
#     Epoch 19/30 | train loss=0.0172 AUC=1.0000 | val loss=0.8222 AUC=0.7655
#     Epoch 20/30 | train loss=0.0144 AUC=1.0000 | val loss=0.8339 AUC=0.7791
#     Epoch 21/30 | train loss=0.0109 AUC=1.0000 | val loss=0.8194 AUC=0.7784
#     Epoch 22/30 | train loss=0.0233 AUC=0.9999 | val loss=0.8186 AUC=0.7824
#     Epoch 23/30 | train loss=0.0121 AUC=1.0000 | val loss=0.8210 AUC=0.7716
#     Epoch 24/30 | train loss=0.0115 AUC=1.0000 | val loss=0.8378 AUC=0.7764
#     Epoch 26/30 | train loss=0.0178 AUC=1.0000 | val loss=0.8334 AUC=0.7656
#     Epoch 27/30 | train loss=0.0189 AUC=1.0000 | val loss=0.8304 AUC=0.7674
#     Epoch 28/30 | train loss=0.0176 AUC=1.0000 | val loss=0.8537 AUC=0.7607
#     Epoch 29/30 | train loss=0.0206 AUC=1.0000 | val loss=0.8436 AUC=0.7650
#     Epoch 30/30 | train loss=0.0200 AUC=1.0000 | val loss=0.8842 AUC=0.7589
#   Fold 5/5 finished | best AUC=0.7821
# Seed 42 OOF AUC = 0.7488
#
# Finished. Mean-prediction OOF AUC = 0.7488
# Saved to: /content/drive/MyDrive/QC/results/test_school_layer4

# %%
import numpy as np
import pandas as pd
from sklearn.metrics import roc_auc_score

# ============================================================
# Settings
# ============================================================
OOF_PATH = (
    "/content/drive/MyDrive/QC/results/"
    "test_school_layer4/oof_predictions.csv"
)

PATIENT_COL = "patient_id"
LABEL_COL = "label"

SEEDS = [42, ]
#SEEDS = [42, 43, 44, 45, 46]   # 本解析では5 seeds
N_BOOT = 2000
RANDOM_STATE = 12345


# ============================================================
# Load
# ============================================================
df = pd.read_csv(OOF_PATH)

pred_cols = [f"oof_seed{s}" for s in SEEDS]

missing = [c for c in pred_cols if c not in df.columns]
if missing:
    raise ValueError(
        f"Missing prediction columns: {missing}\n"
        "まだ1 seedしか実行していない場合は SEEDS=[42] にしてください。"
    )

print("Images:", len(df))
print("Patients:", df[PATIENT_COL].nunique())


# ============================================================
# 1. Patient-level aggregation
#    複数画像を持つ患者では予測確率を平均
# ============================================================
# 患者内でlabelが一貫しているか確認
label_check = df.groupby(PATIENT_COL)[LABEL_COL].nunique()

if (label_check > 1).any():
    bad_ids = label_check[label_check > 1].index.tolist()
    raise ValueError(
        f"同一患者内でlabelが不一致です: {bad_ids[:10]}"
    )

agg_dict = {
    LABEL_COL: "first",
}

for col in pred_cols:
    agg_dict[col] = "mean"

patient_df = (
    df.groupby(PATIENT_COL, as_index=False)
      .agg(agg_dict)
)

print("\nPatient-level dataset")
print(patient_df.shape)
print(patient_df[LABEL_COL].value_counts())


# ============================================================
# 2. Seedごとの patient-level OOF AUROC
# ============================================================
seed_results = []

y = patient_df[LABEL_COL].astype(int).to_numpy()

for seed in SEEDS:
    col = f"oof_seed{seed}"
    pred = patient_df[col].to_numpy()

    auc = roc_auc_score(y, pred)

    seed_results.append({
        "seed": seed,
        "patient_level_auc": auc
    })

seed_results = pd.DataFrame(seed_results)

mean_auc = seed_results["patient_level_auc"].mean()

# sample SD
sd_auc = seed_results["patient_level_auc"].std(ddof=1) if len(SEEDS) > 1 else np.nan


# ============================================================
# 3. Primary prediction
#    5 seedsのpatient-level OOF予測を平均
# ============================================================
patient_df["oof_mean_seeds"] = patient_df[pred_cols].mean(axis=1)

primary_pred = patient_df["oof_mean_seeds"].to_numpy()

primary_auc = roc_auc_score(y, primary_pred)


# ============================================================
# 4. Patient-level stratified bootstrap
#
#    患者単位でresampling。
#    Female / Maleをそれぞれ復元抽出してclass balanceを保持。
# ============================================================
def bootstrap_auc_patient_level(
    y_true,
    y_pred,
    n_boot=5000,
    random_state=12345
):
    y_true = np.asarray(y_true)
    y_pred = np.asarray(y_pred)

    rng = np.random.default_rng(random_state)

    idx0 = np.where(y_true == 0)[0]
    idx1 = np.where(y_true == 1)[0]

    boot_aucs = []

    for _ in range(n_boot):

        # classごとにpatientを復元抽出
        boot0 = rng.choice(
            idx0,
            size=len(idx0),
            replace=True
        )

        boot1 = rng.choice(
            idx1,
            size=len(idx1),
            replace=True
        )

        boot_idx = np.concatenate([boot0, boot1])

        auc = roc_auc_score(
            y_true[boot_idx],
            y_pred[boot_idx]
        )

        boot_aucs.append(auc)

    boot_aucs = np.asarray(boot_aucs)

    ci_lower = np.percentile(boot_aucs, 2.5)
    ci_upper = np.percentile(boot_aucs, 97.5)

    return ci_lower, ci_upper, boot_aucs


ci_low, ci_high, boot_aucs = bootstrap_auc_patient_level(
    y,
    primary_pred,
    n_boot=N_BOOT,
    random_state=RANDOM_STATE
)


# ============================================================
# 5. Results
# ============================================================
print("\n==========================================")
print("PRIMARY ANALYSIS")
print("==========================================")

print(
    f"Patient-level AUROC = {primary_auc:.3f} "
    f"(95% CI {ci_low:.3f}-{ci_high:.3f})"
)

print("\n==========================================")
print("SEED-LEVEL REPRODUCIBILITY")
print("==========================================")

display(seed_results)

if len(SEEDS) > 1:
    print(
        f"5-seed AUROC mean ± SD = "
        f"{mean_auc:.3f} ± {sd_auc:.3f}"
    )
else:
    print(
        f"Seed {SEEDS[0]} AUROC = {mean_auc:.3f}"
    )


# ============================================================
# 6. Save
# ============================================================
# summary = pd.DataFrame([{
#     "n_patients": len(patient_df),
#     "primary_patient_auc": primary_auc,
#     "bootstrap_ci_lower": ci_low,
#     "bootstrap_ci_upper": ci_high,
#     "n_bootstrap": N_BOOT,
#     "seed_auc_mean": mean_auc,
#     "seed_auc_sd": sd_auc,
#     "n_seeds": len(SEEDS),
# }])

# summary.to_csv(
#     "/content/drive/MyDrive/QC/results/"
#     "patient_level_auc_summary.csv",
#     index=False
# )

# seed_results.to_csv(
#     "/content/drive/MyDrive/QC/results/"
#     "patient_level_seed_auc.csv",
#     index=False
# )

# patient_df.to_csv(
#     "/content/drive/MyDrive/QC/results/"
#     "patient_level_oof_predictions.csv",
#     index=False
# )

# print("\nSaved.")
# Out:
# Images: 404
# Patients: 296
#
# Patient-level dataset
# (296, 3)
# label
# 1    161
# 0    135
# Name: count, dtype: int64
#
# ==========================================
# PRIMARY ANALYSIS
# ==========================================
# Patient-level AUROC = 0.748 (95% CI 0.691-0.803)
#
# ==========================================
# SEED-LEVEL REPRODUCIBILITY
# ==========================================
#    seed  patient_level_auc
# 0    42           0.748056
# Seed 42 AUROC = 0.748

# %% [markdown]
# # 12-17

# %%
from pediatric_resnet_ft import build_dataset_csv

df_young = build_dataset_csv(
    metadata_path="/content/drive/MyDrive/PedAI_ChestXp/For_finetuning/QC/merged_reviewer_results_260906.xlsx",
    image_dir="/content/drive/MyDrive/PedAI_ChestXp/For_finetuning/QC/age_12_17",
    output_csv="/content/drive/MyDrive/QC/age_12_17.csv",
)

print(df_young.shape)
display(df_young.head())

print("\nImages:", len(df_young))
print("Patients:", df_young["patient_id"].nunique())
print("\nSex:")
print(df_young["label"].value_counts())
# Out:
# (565, 6)
#   patient_id        image_name  \
# 0        911  00000911_001.png
# 1        911  00000911_003.png
# 2        960  00000960_000.png
# 3       1054  00001054_000.png
# 4       1054  00001054_002.png
#
#                                                 path  label  age  age_group
# 0  /content/drive/.shortcut-targets-by-id/18RK_Lq...      1   16  age_12_17
# 1  /content/drive/.shortcut-targets-by-id/18RK_Lq...      1   16  age_12_17
# 2  /content/drive/.shortcut-targets-by-id/18RK_Lq...      0   16  age_12_17
# 3  /content/drive/.shortcut-targets-by-id/18RK_Lq...      1   12  age_12_17
# 4  /content/drive/.shortcut-targets-by-id/18RK_Lq...      1   13  age_12_17
# Images: 565
# Patients: 408
#
# Sex:
# label
# 1    319
# 0    246
# Name: count, dtype: int64

# %%
from pediatric_resnet_ft import run_cv

results = run_cv(
    csv_path="/content/drive/MyDrive/QC/age_12_17.csv",

    pretrained="adult",
    pretrained_path="/content/drive/MyDrive/colab_最小データセット/models/Morimoto_Adult_AgeFixed_20260923_共有用/resnet50_pa_adult_agefixed_morimoto_20260923_weights.pt",

    mode="layer4",

    seeds=[42],
    n_splits=5,

    epochs=30,
    batch_size=16,

    id_col="patient_id",

    output_dir="/content/drive/MyDrive/QC/results/test_adolescent_layer4",)
# Out:
# Device: cuda (Tesla T4)
# CV: 1 seed(s) x 5 folds = 5 models
#
# Seed 1/1 (seed=42)
#   Fold 1/5 | train=461 valid=104
#     Epoch 01/30 | train loss=0.3310 AUC=0.9723 | val loss=0.4691 AUC=0.9192
#     Epoch 02/30 | train loss=0.1750 AUC=0.9865 | val loss=0.4099 AUC=0.9238
#     Epoch 03/30 | train loss=0.1759 AUC=0.9848 | val loss=0.3935 AUC=0.9245
#     Epoch 04/30 | train loss=0.1169 AUC=0.9913 | val loss=0.3971 AUC=0.9230
#     Epoch 05/30 | train loss=0.0834 AUC=0.9962 | val loss=0.4085 AUC=0.9192
#     Epoch 06/30 | train loss=0.0535 AUC=0.9982 | val loss=0.4267 AUC=0.9146
#     Epoch 07/30 | train loss=0.0541 AUC=0.9988 | val loss=0.4449 AUC=0.9154
#     Epoch 08/30 | train loss=0.0271 AUC=0.9997 | val loss=0.4787 AUC=0.9138
#     Epoch 09/30 | train loss=0.0204 AUC=0.9999 | val loss=0.5168 AUC=0.9074
#     Epoch 10/30 | train loss=0.0211 AUC=0.9999 | val loss=0.5461 AUC=0.9051
#     Epoch 11/30 | train loss=0.0220 AUC=0.9998 | val loss=0.5768 AUC=0.9074
#     Epoch 12/30 | train loss=0.0135 AUC=0.9999 | val loss=0.6086 AUC=0.9032
#     Epoch 13/30 | train loss=0.0108 AUC=1.0000 | val loss=0.6177 AUC=0.9009
#     Epoch 14/30 | train loss=0.0085 AUC=1.0000 | val loss=0.6241 AUC=0.9013
#     Epoch 15/30 | train loss=0.0034 AUC=1.0000 | val loss=0.6420 AUC=0.9020
#     Epoch 16/30 | train loss=0.0041 AUC=1.0000 | val loss=0.6584 AUC=0.9009
#     Epoch 17/30 | train loss=0.0069 AUC=1.0000 | val loss=0.6661 AUC=0.8933
#     Epoch 18/30 | train loss=0.0044 AUC=1.0000 | val loss=0.6905 AUC=0.8952
#     Epoch 19/30 | train loss=0.0022 AUC=1.0000 | val loss=0.6992 AUC=0.8967
#     Epoch 21/30 | train loss=0.0035 AUC=1.0000 | val loss=0.5245 AUC=0.9518
#     Epoch 22/30 | train loss=0.0057 AUC=1.0000 | val loss=0.5036 AUC=0.9529
#     Epoch 23/30 | train loss=0.0023 AUC=1.0000 | val loss=0.4934 AUC=0.9527
#     Epoch 24/30 | train loss=0.0029 AUC=1.0000 | val loss=0.4981 AUC=0.9532
#     Epoch 25/30 | train loss=0.0046 AUC=1.0000 | val loss=0.5151 AUC=0.9541
#     Epoch 26/30 | train loss=0.0028 AUC=1.0000 | val loss=0.5060 AUC=0.9552
#     Epoch 27/30 | train loss=0.0021 AUC=1.0000 | val loss=0.5038 AUC=0.9549
#     Epoch 28/30 | train loss=0.0022 AUC=1.0000 | val loss=0.4968 AUC=0.9544
#     Epoch 29/30 | train loss=0.0020 AUC=1.0000 | val loss=0.5084 AUC=0.9549
#     Epoch 30/30 | train loss=0.0038 AUC=1.0000 | val loss=0.4951 AUC=0.9538
#   Fold 5/5 finished | best AUC=0.9702
# Seed 42 OOF AUC = 0.9717
#
# Finished. Mean-prediction OOF AUC = 0.9717
# Saved to: /content/drive/MyDrive/QC/results/test_adolescent_layer4

# %%
import numpy as np
import pandas as pd
from sklearn.metrics import roc_auc_score

# ============================================================
# Settings
# ============================================================
OOF_PATH = (
    "/content/drive/MyDrive/QC/results/"
    "test_adolescent_layer4/oof_predictions.csv"
)

PATIENT_COL = "patient_id"
LABEL_COL = "label"

SEEDS = [42, ]
#SEEDS = [42, 43, 44, 45, 46]   # 本解析では5 seeds
N_BOOT = 2000
RANDOM_STATE = 12345


# ============================================================
# Load
# ============================================================
df = pd.read_csv(OOF_PATH)

pred_cols = [f"oof_seed{s}" for s in SEEDS]

missing = [c for c in pred_cols if c not in df.columns]
if missing:
    raise ValueError(
        f"Missing prediction columns: {missing}\n"
        "まだ1 seedしか実行していない場合は SEEDS=[42] にしてください。"
    )

print("Images:", len(df))
print("Patients:", df[PATIENT_COL].nunique())


# ============================================================
# 1. Patient-level aggregation
#    複数画像を持つ患者では予測確率を平均
# ============================================================
# 患者内でlabelが一貫しているか確認
label_check = df.groupby(PATIENT_COL)[LABEL_COL].nunique()

if (label_check > 1).any():
    bad_ids = label_check[label_check > 1].index.tolist()
    raise ValueError(
        f"同一患者内でlabelが不一致です: {bad_ids[:10]}"
    )

agg_dict = {
    LABEL_COL: "first",
}

for col in pred_cols:
    agg_dict[col] = "mean"

patient_df = (
    df.groupby(PATIENT_COL, as_index=False)
      .agg(agg_dict)
)

print("\nPatient-level dataset")
print(patient_df.shape)
print(patient_df[LABEL_COL].value_counts())


# ============================================================
# 2. Seedごとの patient-level OOF AUROC
# ============================================================
seed_results = []

y = patient_df[LABEL_COL].astype(int).to_numpy()

for seed in SEEDS:
    col = f"oof_seed{seed}"
    pred = patient_df[col].to_numpy()

    auc = roc_auc_score(y, pred)

    seed_results.append({
        "seed": seed,
        "patient_level_auc": auc
    })

seed_results = pd.DataFrame(seed_results)

mean_auc = seed_results["patient_level_auc"].mean()

# sample SD
sd_auc = seed_results["patient_level_auc"].std(ddof=1) if len(SEEDS) > 1 else np.nan


# ============================================================
# 3. Primary prediction
#    5 seedsのpatient-level OOF予測を平均
# ============================================================
patient_df["oof_mean_seeds"] = patient_df[pred_cols].mean(axis=1)

primary_pred = patient_df["oof_mean_seeds"].to_numpy()

primary_auc = roc_auc_score(y, primary_pred)


# ============================================================
# 4. Patient-level stratified bootstrap
#
#    患者単位でresampling。
#    Female / Maleをそれぞれ復元抽出してclass balanceを保持。
# ============================================================
def bootstrap_auc_patient_level(
    y_true,
    y_pred,
    n_boot=5000,
    random_state=12345
):
    y_true = np.asarray(y_true)
    y_pred = np.asarray(y_pred)

    rng = np.random.default_rng(random_state)

    idx0 = np.where(y_true == 0)[0]
    idx1 = np.where(y_true == 1)[0]

    boot_aucs = []

    for _ in range(n_boot):

        # classごとにpatientを復元抽出
        boot0 = rng.choice(
            idx0,
            size=len(idx0),
            replace=True
        )

        boot1 = rng.choice(
            idx1,
            size=len(idx1),
            replace=True
        )

        boot_idx = np.concatenate([boot0, boot1])

        auc = roc_auc_score(
            y_true[boot_idx],
            y_pred[boot_idx]
        )

        boot_aucs.append(auc)

    boot_aucs = np.asarray(boot_aucs)

    ci_lower = np.percentile(boot_aucs, 2.5)
    ci_upper = np.percentile(boot_aucs, 97.5)

    return ci_lower, ci_upper, boot_aucs


ci_low, ci_high, boot_aucs = bootstrap_auc_patient_level(
    y,
    primary_pred,
    n_boot=N_BOOT,
    random_state=RANDOM_STATE
)


# ============================================================
# 5. Results
# ============================================================
print("\n==========================================")
print("PRIMARY ANALYSIS")
print("==========================================")

print(
    f"Patient-level AUROC = {primary_auc:.3f} "
    f"(95% CI {ci_low:.3f}-{ci_high:.3f})"
)

print("\n==========================================")
print("SEED-LEVEL REPRODUCIBILITY")
print("==========================================")

display(seed_results)

if len(SEEDS) > 1:
    print(
        f"5-seed AUROC mean ± SD = "
        f"{mean_auc:.3f} ± {sd_auc:.3f}"
    )
else:
    print(
        f"Seed {SEEDS[0]} AUROC = {mean_auc:.3f}"
    )


# ============================================================
# 6. Save
# ============================================================
# summary = pd.DataFrame([{
#     "n_patients": len(patient_df),
#     "primary_patient_auc": primary_auc,
#     "bootstrap_ci_lower": ci_low,
#     "bootstrap_ci_upper": ci_high,
#     "n_bootstrap": N_BOOT,
#     "seed_auc_mean": mean_auc,
#     "seed_auc_sd": sd_auc,
#     "n_seeds": len(SEEDS),
# }])

# summary.to_csv(
#     "/content/drive/MyDrive/QC/results/"
#     "patient_level_auc_summary.csv",
#     index=False
# )

# seed_results.to_csv(
#     "/content/drive/MyDrive/QC/results/"
#     "patient_level_seed_auc.csv",
#     index=False
# )

# patient_df.to_csv(
#     "/content/drive/MyDrive/QC/results/"
#     "patient_level_oof_predictions.csv",
#     index=False
# )

# print("\nSaved.")
# Out:
# Images: 565
# Patients: 408
#
# Patient-level dataset
# (408, 3)
# label
# 1    239
# 0    169
# Name: count, dtype: int64
#
# ==========================================
# PRIMARY ANALYSIS
# ==========================================
# Patient-level AUROC = 0.970 (95% CI 0.954-0.984)
#
# ==========================================
# SEED-LEVEL REPRODUCIBILITY
# ==========================================
#    seed  patient_level_auc
# 0    42            0.96982
# Seed 42 AUROC = 0.970
